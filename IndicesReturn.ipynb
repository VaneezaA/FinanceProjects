# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source = 'yahoo', start = '1995-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC       ^IXIC       ^GDAXI
# Date
# 1995-01-03  459.109985  743.580017  2068.919922
# 1995-01-04  460.709991  745.840027  2072.899902
# 1995-01-05  460.339996  745.659973  2051.459961
# 1995-01-06  460.679993  749.690002  2058.199951
# 1995-01-09  460.829987  752.090027  2053.409912

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI
# Date
# 2019-05-13  2811.870117  7647.020020  11876.650391
# 2019-05-14  2834.409912  7734.490234  11991.620117
# 2019-05-15  2850.959961  7822.149902  12099.570312
# 2019-05-16  2876.320068  7898.049805  12310.370117
# 2019-05-17  2859.530029  7816.284668  12238.940430

# %%
# Normalization to 100 = Pt/P0 * 100
(ind_data/ind_data.iloc[0]*100).plot(figsize = (15,6));
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ind_returns = (ind_data / ind_data.shift(1))-1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2019-05-13 -0.024131 -0.034094 -0.015189
# 2019-05-14  0.008016  0.011438  0.009680
# 2019-05-15  0.005839  0.011334  0.009002
# 2019-05-16  0.008895  0.009703  0.017422
# 2019-05-17 -0.005837 -0.010353 -0.005802

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.091432
# ^IXIC     0.125082
# ^GDAXI    0.087124
# dtype: float64

# %%
# Let's see if a certain stock out or underperforms the market

# %%
tickers = ['^GSPC', 'LULU','F', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source = 'yahoo', start = '2010-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                   ^GSPC        LULU      F          ^DJI
# Date
# 2019-05-13  2811.870117  167.570007  10.08  25324.990234
# 2019-05-14  2834.409912  170.679993  10.24  25532.050781
# 2019-05-15  2850.959961  172.880005  10.36  25648.019531
# 2019-05-16  2876.320068  176.800003  10.40  25862.679688
# 2019-05-17  2859.530029  173.000000  10.29  25764.000000

# %%
# Normalize the data

(data_2/ data_2.iloc[0] * 100).plot(figsize = (15,7));
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# LULU outperformed by a great deal
# Ford underperformed for the most part with some outperformance moments
